# %%
import pandas as pd
import numpy as np

# %%
#export csvs 
# Save file path to variable
intake = "CSV/intake.csv"
outcome = "CSV/outcome.csv"
intake_df = pd.read_csv(intake)
outcome_df = pd.read_csv(outcome)
intake_df.head()
# Out:
#   Animal ID      Name         DateTime        MonthYear  \
# 0   A748291  *Madison   5/1/2017 14:26   5/1/2017 14:26
# 1   A750529       NaN  5/28/2017 13:22  5/28/2017 13:22
# 2   A730601       NaN   7/7/2016 12:11   7/7/2016 12:11
# 3   A748238       NaN   5/1/2017 10:53   5/1/2017 10:53
# 4   A683644     *Zoey  7/13/2014 11:02  7/13/2014 11:02
#
#                                       Found Location      Intake Type  \
# 0  S Pleasant Valley Rd And E Riverside Dr in Aus...            Stray
# 1                    8312 North Ih 35 in Austin (TX)            Stray
# 2                       1109 Shady Ln in Austin (TX)            Stray
# 3     Airport Blvd And Oak Springs Dr in Austin (TX)            Stray
# 4                                        Austin (TX)  Owner Surrender
#
#   Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0           Normal         Dog   Intact Female       10 months
# 1           Normal         Dog   Intact Female        5 months
# ...

# %%
#merge the two data framese
animal_df = pd.merge(intake_df, outcome_df, on="Animal ID", how="outer")
