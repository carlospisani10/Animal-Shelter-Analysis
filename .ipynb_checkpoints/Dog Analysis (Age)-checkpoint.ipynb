# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#map csv
austin = "CSV/MergedData.csv"
#austin_df = pd.read_csv(austin)
austin_df = pd.read_csv(austin, encoding = 'latin-1')
austin_df.head()
# Out:
#   Animal ID Name_intake         DateTime_intake  \
# 0   A748291    *Madison  05/01/2017 02:26:00 PM
# 1   A750529         NaN  05/28/2017 01:22:00 PM
# 2   A730601         NaN  07/07/2016 12:11:00 PM
# 3   A748238         NaN  05/01/2017 10:53:00 AM
# 4   A683644       *Zoey  07/13/2014 11:02:00 AM
#
#                                       Found Location      Intake Type  \
# 0  S Pleasant Valley Rd And E Riverside Dr in Aus...            Stray
# 1                    8312 North Ih 35 in Austin (TX)            Stray
# 2                       1109 Shady Ln in Austin (TX)            Stray
# 3     Airport Blvd And Oak Springs Dr in Austin (TX)            Stray
# 4                                        Austin (TX)  Owner Surrender
#
#   Intake Condition Animal Type_intake Sex upon Intake Age upon Intake  \
# 0           Normal                Dog   Intact Female       10 months
# 1           Normal                Dog   Intact Female        5 months
# ...

# %%
dog_df = austin_df.loc[(austin_df['Animal Type_intake'] == "Dog"), : ]
dog_df.head()
# Out:
#   Animal ID Name_intake         DateTime_intake  \
# 0   A748291    *Madison  05/01/2017 02:26:00 PM
# 1   A750529         NaN  05/28/2017 01:22:00 PM
# 3   A748238         NaN  05/01/2017 10:53:00 AM
# 4   A683644       *Zoey  07/13/2014 11:02:00 AM
# 5   A676515        Rico  04/11/2014 08:45:00 AM
#
#                                       Found Location      Intake Type  \
# 0  S Pleasant Valley Rd And E Riverside Dr in Aus...            Stray
# 1                    8312 North Ih 35 in Austin (TX)            Stray
# 3     Airport Blvd And Oak Springs Dr in Austin (TX)            Stray
# 4                                        Austin (TX)  Owner Surrender
# 5                      615 E. Wonsley in Austin (TX)            Stray
#
#   Intake Condition Animal Type_intake Sex upon Intake Age upon Intake  \
# 0           Normal                Dog   Intact Female       10 months
# 1           Normal                Dog   Intact Female        5 months
# ...

# %%
dog_df["AgeYears_Outcome"] = round(dog_df["AgeDays_outcome"] / 365,2)
age_bins = [0,1,3,5,7,9, 25]
age_labels = ["<1", "1-3", "3-5", "5-7", "7-9", ">9"]
dog_df.head()

#Make Bins for Age
#hp_bins = [180, 200, 350, 400]
#hp_labels = ["Slow", "Decent", "Fast"]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#   Animal ID Name_intake         DateTime_intake  \
# 0   A748291    *Madison  05/01/2017 02:26:00 PM
# 1   A750529         NaN  05/28/2017 01:22:00 PM
# 3   A748238         NaN  05/01/2017 10:53:00 AM
# 4   A683644       *Zoey  07/13/2014 11:02:00 AM
# 5   A676515        Rico  04/11/2014 08:45:00 AM
#
#                                       Found Location      Intake Type  \
# 0  S Pleasant Valley Rd And E Riverside Dr in Aus...            Stray
# 1                    8312 North Ih 35 in Austin (TX)            Stray
# 3     Airport Blvd And Oak Springs Dr in Austin (TX)            Stray
# ...

# %%
age_bins = [0,1,3,5,7,9, 25]
age_labels = ["<1", "1-3", "3-5", "5-7", "7-9", ">9"]
dog_df["Age Range"] = pd.cut(dog_df["AgeYears_Outcome"], age_bins, labels=age_labels)
dog_group = dog_df.groupby("Age Range")
dog_groups = dog_group["Outcome Type"].value_counts()
dog_groups_df = pd.DataFrame(dog_groups)
dog_groups_df.unstack(level = 0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                 Outcome Type
# Age Range                 <1     1-3     3-5    5-7    7-9     >9
# Outcome Type
# Adoption              8642.0  3119.0   953.0  495.0  330.0  291.0
# Died                    65.0    25.0     6.0    5.0    8.0   13.0
# Disposal                 3.0     5.0     1.0    NaN    NaN    1.0
# Euthanasia             309.0   394.0   155.0   92.0   92.0  217.0
# Missing                  5.0     3.0     2.0    NaN    NaN    1.0
# Return to Owner       2206.0  2529.0  1203.0  847.0  625.0  958.0
# ...

# %%
test= dog_groups_df.loc[('<1', ["Adoption"]), : ]
# Out:
# ---------------------------------------------------------------------------
# UnsortedIndexError                        Traceback (most recent call last)
# <ipython-input-7-cfb9729d0b17> in <module>()
# ----> 1 test= dog_groups_df.loc[('<1', ["Adoption"]), : ]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     834     def _getitem_tuple(self, tup):
#     835         try:
# --> 836             return self._getitem_lowerdim(tup)
#     837         except IndexingError:
#     838             pass
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
# ...
